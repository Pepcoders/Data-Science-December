# %% [markdown]
# <a href="https://colab.research.google.com/github/aman5898/Data-Science-December/blob/main/Python_Basics_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Pepcoding")
# Out:
# Hello Pepcoding

# %%
num = 10

# %%
string = "Pepcoding"

# %%
flt = 2.2

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
print(type(string))
print(type(flt))
# Out:
# <class 'str'>
# <class 'float'>

# %%
print(type(num),type(string),type(flt))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %%
a,b,c = 10,20,30

# %%
print(a,b,c)
# Out:
# 10 20 30

# %%
a=b=c=50

# %%
print(a,b,c)
# Out:
# 50 50 50

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
num1 = 10

# %%
num2 = 4.4
num3 = 5+8j

# %%
print(num1,num2,num3)
# Out:
# 10 4.4 (5+8j)

# %% [markdown]
# ### String

# %%
phrase = "Pepcoding"

# %%
print(phrase[0])
# Out:
# P

# %%
phrase[0]='i'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2c2bee793f88> in <module>()
# ----> 1 phrase[0]='i'
#
# TypeError: 'str' object does not support item assignment

# %%
phrase[0:3]
# Out:
# 'Pep'

# %%
phrase[0:]
# Out:
# 'Pepcoding'

# %%
phrase[:3]
# Out:
# 'Pep'

# %%
phrase[:]
# Out:
# 'Pepcoding'

# %%
phrase[0:5:2]
# Out:
# 'Ppo'

# %%
phrase[7:1:1]
# Out:
# ''

# %%
phrase[7:1:-1]
# Out:
# 'nidocp'

# %%
phrase[-1]
# Out:
# 'g'

# %%
phrase[-1:-5:-1]
# Out:
# 'gnid'

# %%
phrase[::-1]
# Out:
# 'gnidocpeP'

# %%
len(phrase)
# Out:
# 9

# %%
phrase[-1:-9:-1]
# Out:
# 'gnidocpe'

# %%
phrase[10:1]
# Out:
# ''

# %%
for ch in phrase:
  print(ch)
# Out:
# P
# e
# p
# c
# o
# d
# i
# n
# g

# %%
if "Pep" in phrase:
  print("Hello")
# Out:
# Hello

# %%
phrase.upper()
# Out:
# 'PEPCODING'

# %%
phrase.lower()
# Out:
# 'pepcoding'

# %%
string = "My name is Anthony Gonsalvis"

str2 = string.split(" ")
print(str2)
# Out:
# ['My', 'name', 'is', 'Anthony', 'Gonsalvis']

# %%
print(str2)
# Out:
# ['My', 'name', 'is', 'Anthony', 'Gonsalvis']

# %%
if 1>2:
  print("Hello JI")
else:
  print("Na ji")
# Out:
# Na ji

# %%
marks = 89

# %%
if marks>90:
  print("A+")
  if marks>95:
    print("Super Brilliant")
elif marks>80:
  print("B+")
else:
  print("fail")
# Out:
# B+

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,5):
  print(i)
  for j in range(5,10):
    print(j)
# Out:
# 2
# 5
# 6
# 7
# 8
# 9
# 3
# 5
# 6
# 7
# 8
# 9
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(5):
  print(str(i)+" Hello")
  if i ==2:
    break
# Out:
# 0 Hello
# 1 Hello
# 2 Hello

# %%
for i in range(5):
  if i ==2:
    continue
  print(str(i)+" Hello")
# Out:
# 0 Hello
# 1 Hello
# 3 Hello
# 4 Hello

# %%
for i in range(5):
  if i ==2:
    continue 
    print(str(i)+"hello")

# %% [markdown]
# ### List [ ]

# %%
lst = [1,5,6]

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
lst.append(7)

# %%
lst.append("Pepcoding")

# %%
print(lst)
# Out:
# [500, 5, 6, 7, 'Pepcoding']

# %%
lst[0]=500

# %%
lst2 = [1,1]

# %%
lst2.append(lst)

# %%
print(lst2)
# Out:
# [1, 1, [500, 5, 6, 7, 'Pepcoding']]

# %%
lst.append(5)

# %%
print(lst)
# Out:
# [500, 5, 6, 7, 'Pepcoding', 5]

# %%
lst[-1]
# Out:
# 5

# %%
lst[0:2]
# Out:
# [500, 5]

# %%
lst.insert(2,"Pepcoder")

# %%
print(lst)
# Out:
# [500, 5, 'Pepcoder', 6, 7, 'Pepcoding', 5]

# %%
lst.remove(6)

# %%
print(lst)
# Out:
# [500, 5, 'Pepcoder', 7, 'Pepcoding']

# %%
print(lst.pop())
# Out:
# 5

# %%
for i in lst:
  print(i)
# Out:
# 500
# 5
# Pepcoder
# 7
# Pepcoding

# %% [markdown]
# ### Tuple( )

# %%
tup = (1,2,3,"Hello")

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup = 1,2,3,"Hello"

# %%
tup2 = (99,)

# %%
print(type(tup2))
# Out:
# <class 'tuple'>

# %%
print(tup[0])
# Out:
# 1

# %%
tup[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-aeb61b0651cd> in <module>()
# ----> 1 tup[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in tup:
  print(i)
# Out:
# 1
# 2
# 3
# Hello

# %%
tup.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-4c22b886f1e9> in <module>()
# ----> 1 tup.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ### Set { }

# %%
st = {"Apple","Banana","Mango"}

# %%
print(st)
# Out:
# {'Banana', 'Mango', 'Apple'}

# %%
st[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-028cc1d9138b> in <module>()
# ----> 1 st[0]
#
# TypeError: 'set' object is not subscriptable

# %%
st = {"Apple","Banana","Mango","Banana",5,6}

# %%
st
# Out:
# {5, 6, 'Apple', 'Mango', 'Orange'}

# %%
#sets are immutable

st.add("Orange")

# %%
st.remove('Banana')

# %%
st = {1,2,3,["Apple","orange"]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1484a43af00d> in <module>()
# ----> 1 st = {1,2,3,["Apple","orange"]}
#
# TypeError: unhashable type: 'list'

# %%
st = {1,2,3,("Apple","orange")}

# %%
st
# Out:
# {('Apple', 'orange'), 1, 2, 3}

# %%
for x in st:
  print(x)
# Out:
# 1
# 2
# 3
# ('Apple', 'orange')

# %%
st.pop()
# Out:
# 1

# %%
st.clear()

# %%
st
# Out:
# set()

# %%
del st

# %%
st
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-235690c2c180> in <module>()
# ----> 1 st
#
# NameError: name 'st' is not defined

# %%
set1 = {1,2,3,4,5}
set2 = {2,5,8,9}

print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %% [markdown]
# Dictionary { }

# %%
my_dict = {
    "Name":"Pepper",
    "Age":4,
    "Gender":"Male"
}

# %%
print(my_dict)
# Out:
# {'Name': 'Pepper', 'Age': 4, 'Gender': 'Male'}

# %%
my_dict["Height"] = 5.5

# %%
print(my_dict)
# Out:
# {'Name': 'Pepper', 'Age': 4, 'Gender': 'Male', 'Height': 5.5}

# %%
print(my_dict["Name"])
# Out:
# Pepcoding

# %%
my_dict["Name"] = "Pepcoding"

# %%
my_dict.pop("Height")
# Out:
# 5.5

# %%
del my_dict

# %%
my_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-23f353dd2d1f> in <module>()
# ----> 1 my_dict
#
# NameError: name 'my_dict' is not defined

# %%
for key in my_dict.keys():
  print(key)
# Out:
# Name
# Age
# Gender

# %%
for value in my_dict.values():
  print(value)
# Out:
# Pepper
# 4
# Male

# %%
dict2 = my_dict.copy()

# %%
print(dict2)
# Out:
# {'Name': 'Pepper', 'Age': 4, 'Gender': 'Male'}

# %%
  dict3 = {
      "test":my_dict
  }

# %%
print(dict3)
# Out:
# {'test': {'Name': 'Pepper', 'Age': 4, 'Gender': 'Male'}}

# %%
dict3["new"] = (1,2,3)

# %%
dict3.pop("test")
# Out:
# {'Age': 4, 'Gender': 'Male', 'Name': 'Pepper'}

# %% [markdown]
# ### Try Catch

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-50-0106664d39e8> in <module>()
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
a,b = 5,0
try:
  test = "Hello Peter Parker"
  print(pepcoding)
except ZeroDivisionError:
  print("Division by zero happened")
except NameError:
  print("NameError Came")
except:
  print("Other Exception came")
else:
  print("Else Block Printed")


print("Hello World")
# Out:
# NameError Came
# Hello World

# %%
test = "Hello Peter Parker"
print(Pepcoding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-7089108e90cd> in <module>()
#       1 test = "Hello Peter Parker"
# ----> 2 print(Pepcoding)
#
# NameError: name 'Pepcoding' is not defined

# %%
a,b = 5,0
try:
  test = "Hello Peter Parker"
  print(pepcoding)
except ZeroDivisionError:
  print("Division by zero happened")
except NameError:
  print("NameError Came")
except:
  print("Other Exception came")
else:
  print("Else Block Printed")
finally:
  print("Finally Block Printed")


print("Hello World")
# Out:
# Else Block Printed
# Finally Block Printed
# Hello World

# %%
raise Exception("List is empty")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-63-84d6cd2fc5bb> in <module>()
# ----> 1 raise Exception("List is empty")
#
# Exception: List is empty
