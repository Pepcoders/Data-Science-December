# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-December/blob/main/22-02-21-K_Means/Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(centers = 5, n_samples = 500, random_state = 170)
plt.scatter(X[:, 0], X[:, 1], c = y)

# %%
X.shape, y.shape
# Out:
# ((500, 2), (500,))

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters = 5)
km.fit(X)
plt.scatter(X[:, 0], X[:, 1], c = km.predict(X))
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color = 'r')

# %%
km.cluster_centers_
# Out:
# array([[ 4.83045349, -9.79222442],
#        [-4.43476506,  0.09567152],
#        [ 8.85702444, -0.70712247],
#        [-9.09886114, -5.42284517],
#        [ 2.04702852,  0.57552133]])

# %%
km.inertia_
# Out:
# 978.926999640222

# %%
error = []

for k in range(1, 20):
    km = KMeans(n_clusters = k)
    km.fit(X)
    error.append(km.inertia_)

# %%
plt.figure(figsize = (10, 8))

plt.plot(range(1, len(error)+1), error)

# %% [markdown]
# # Fail Case

# %%
from sklearn.datasets import make_moons

X, y = make_moons(noise = 0.15, n_samples = 500)
plt.scatter(X[:, 0], X[:, 1], c = y)

# %%
km = KMeans(n_clusters = 2)
y_pred = km.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c = y_pred)
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color = 'r')
